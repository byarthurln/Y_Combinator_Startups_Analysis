# %%
import pandas as pd
import numpy as np

# Load the data
df = pd.read_csv('/content/2024-05-11-yc-companies.csv')
df.head()
# Out:
#    company_id   company_name  \
# 0       29523   K-Scale Labs
# 1       29519  Forge Rewards
# 2       29517    RetailReady
# 3       29610     Hamming AI
# 4       29518        FanCave
#
#                                    short_description  \
# 0                        Open-source humanoid robots
# 1  All-in-one operations software to power restau...
# 2       An AI-powered supply chain compliance engine
# 3                                 Making AI reliable
# 4         Powering the free agency of college sports
#
#                                     long_description batch  status  \
# 0  We're building humanoid robots to do most of w...   W24  Active
# 1  Forge is the modern operations software for em...   W24  Active
# 2  Every time workers in a warehouse box an order...   W24  Active
# 3  If 2023 was the year of AI POCs, 2024 is the y...   S24  Active
# 4  FanCave powers the free agency of college spor...   W24  Active
#
#                                                 tags          location  \
# 0  ['artificial-intelligence', 'machine-learning'...          New York
# 1                     ['fintech', 'food-tech', 'ai']     San Francisco
# 2  ['b2b', 'compliance', 'logistics', 'supply-cha...               NaN
# 3  ['artificial-intelligence', 'developer-tools',...     San Francisco
# 4  ['marketplace', 'sports-tech', 'consumer', 'en...  Roeland Park, KS
#
#   country  year_founded  num_founders  \
# 0      US        2024.0             3
# 1      US        2023.0             2
# 2     NaN        2024.0             2
# 3      US        2024.0             2
# 4      US        2024.0             2
#
#                                       founders_names  team_size  \
# 0  ['Benjamin Bolte', 'Pawel Budzianowski', 'Matt...        3.0
# 1                       ['Ethan Chang', 'Isaac Kan']        2.0
# 2                      ['Elle Smyth', 'Sarah Hamer']        3.0
# 3             ['Marius Buleandra', 'Sumanyu Sharma']        2.0
# 4                      ['Luke Bogus', 'Nick Siscoe']        2.0
#
#                           website  \
# 0             https://kscale.dev/
# 1   https://www.forgerewards.com/
# 2  https://www.retailreadyai.com/
# 3             https://hamming.ai/
# 4          https://www.fancave.me
#
#                                               cb_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  https://www.crunchbase.com/organization/hammin...
# 4                                                NaN
#
#                                       linkedin_url
# 0         https://www.linkedin.com/company/kscale/
# 1        https://linkedin.com/company/forgerewards
# 2  https://www.linkedin.com/company/retailreadyai/
# 3     https://www.linkedin.com/company/hamming-ai/
# 4        https://www.linkedin.com/company/fancave/

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4663 entries, 0 to 4662
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   company_id         4663 non-null   int64
#  1   company_name       4663 non-null   object
#  2   short_description  4463 non-null   object
#  3   long_description   4333 non-null   object
#  4   batch              4663 non-null   object
#  5   status             4663 non-null   object
#  6   tags               4663 non-null   object
#  7   location           4393 non-null   object
#  8   country            4400 non-null   object
#  9   year_founded       3583 non-null   float64
#  10  num_founders       4663 non-null   int64
#  11  founders_names     4663 non-null   object
#  12  team_size          4591 non-null   float64
#  13  website            4662 non-null   object
#  14  cb_url             2596 non-null   object
#  15  linkedin_url       2994 non-null   object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 583.0+ KB

# %%
df['country'] = df['country'].replace('US', 'USA')
df.to_csv('/content/sample_data/2024-05-11-yc-companies.csv', index=False)
df.head()
# Out:
#    company_id   company_name  \
# 0       29523   K-Scale Labs
# 1       29519  Forge Rewards
# 2       29517    RetailReady
# 3       29610     Hamming AI
# 4       29518        FanCave
#
#                                    short_description  \
# 0                        Open-source humanoid robots
# 1  All-in-one operations software to power restau...
# 2       An AI-powered supply chain compliance engine
# 3                                 Making AI reliable
# 4         Powering the free agency of college sports
#
#                                     long_description batch  status  \
# 0  We're building humanoid robots to do most of w...   W24  Active
# 1  Forge is the modern operations software for em...   W24  Active
# 2  Every time workers in a warehouse box an order...   W24  Active
# 3  If 2023 was the year of AI POCs, 2024 is the y...   S24  Active
# 4  FanCave powers the free agency of college spor...   W24  Active
#
#                                                 tags          location  \
# 0  ['artificial-intelligence', 'machine-learning'...          New York
# 1                     ['fintech', 'food-tech', 'ai']     San Francisco
# 2  ['b2b', 'compliance', 'logistics', 'supply-cha...               NaN
# 3  ['artificial-intelligence', 'developer-tools',...     San Francisco
# 4  ['marketplace', 'sports-tech', 'consumer', 'en...  Roeland Park, KS
#
#   country  year_founded  num_founders  \
# 0     USA        2024.0             3
# 1     USA        2023.0             2
# 2     NaN        2024.0             2
# 3     USA        2024.0             2
# 4     USA        2024.0             2
#
#                                       founders_names  team_size  \
# 0  ['Benjamin Bolte', 'Pawel Budzianowski', 'Matt...        3.0
# 1                       ['Ethan Chang', 'Isaac Kan']        2.0
# 2                      ['Elle Smyth', 'Sarah Hamer']        3.0
# 3             ['Marius Buleandra', 'Sumanyu Sharma']        2.0
# 4                      ['Luke Bogus', 'Nick Siscoe']        2.0
#
#                           website  \
# 0             https://kscale.dev/
# 1   https://www.forgerewards.com/
# 2  https://www.retailreadyai.com/
# 3             https://hamming.ai/
# 4          https://www.fancave.me
#
#                                               cb_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  https://www.crunchbase.com/organization/hammin...
# 4                                                NaN
#
#                                       linkedin_url
# 0         https://www.linkedin.com/company/kscale/
# 1        https://linkedin.com/company/forgerewards
# 2  https://www.linkedin.com/company/retailreadyai/
# 3     https://www.linkedin.com/company/hamming-ai/
# 4        https://www.linkedin.com/company/fancave/

# %% [markdown]
# # Modification of team size values

# %%
# Handle missing or non-finite values in the 'team_size' column
df['team_size'] = df['team_size'].fillna(0)  # Replace missing values with 0 or another default value
# Check if values are finite before converting to integers
df['team_size'] = df['team_size'].apply(lambda x: int(x) if pd.notna(x) and not np.isinf(x) else 0)
# Save the updated data
df.to_csv('/content/sample_data/2024-05-11-yc-companies.csv', index=False)
df.head()
# Out:
#    company_id   company_name  \
# 0       29523   K-Scale Labs
# 1       29519  Forge Rewards
# 2       29517    RetailReady
# 3       29610     Hamming AI
# 4       29518        FanCave
#
#                                    short_description  \
# 0                        Open-source humanoid robots
# 1  All-in-one operations software to power restau...
# 2       An AI-powered supply chain compliance engine
# 3                                 Making AI reliable
# 4         Powering the free agency of college sports
#
#                                     long_description batch  status  \
# 0  We're building humanoid robots to do most of w...   W24  Active
# 1  Forge is the modern operations software for em...   W24  Active
# 2  Every time workers in a warehouse box an order...   W24  Active
# 3  If 2023 was the year of AI POCs, 2024 is the y...   S24  Active
# 4  FanCave powers the free agency of college spor...   W24  Active
#
#                                                 tags          location  \
# 0  ['artificial-intelligence', 'machine-learning'...          New York
# 1                     ['fintech', 'food-tech', 'ai']     San Francisco
# 2  ['b2b', 'compliance', 'logistics', 'supply-cha...               NaN
# 3  ['artificial-intelligence', 'developer-tools',...     San Francisco
# 4  ['marketplace', 'sports-tech', 'consumer', 'en...  Roeland Park, KS
#
#   country  year_founded  num_founders  \
# 0     USA        2024.0             3
# 1     USA        2023.0             2
# 2     NaN        2024.0             2
# 3     USA        2024.0             2
# 4     USA        2024.0             2
#
#                                       founders_names  team_size  \
# 0  ['Benjamin Bolte', 'Pawel Budzianowski', 'Matt...          3
# 1                       ['Ethan Chang', 'Isaac Kan']          2
# 2                      ['Elle Smyth', 'Sarah Hamer']          3
# 3             ['Marius Buleandra', 'Sumanyu Sharma']          2
# 4                      ['Luke Bogus', 'Nick Siscoe']          2
#
#                           website  \
# 0             https://kscale.dev/
# 1   https://www.forgerewards.com/
# 2  https://www.retailreadyai.com/
# 3             https://hamming.ai/
# 4          https://www.fancave.me
#
#                                               cb_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  https://www.crunchbase.com/organization/hammin...
# 4                                                NaN
#
#                                       linkedin_url
# 0         https://www.linkedin.com/company/kscale/
# 1        https://linkedin.com/company/forgerewards
# 2  https://www.linkedin.com/company/retailreadyai/
# 3     https://www.linkedin.com/company/hamming-ai/
# 4        https://www.linkedin.com/company/fancave/

# %%
# Check for missing or empty values in the 'year_founded' column
nan_or_empty_rows = df[df['year_founded'].isna() | (df['year_founded'].astype(str).str.strip() == '')]

# Display the number of rows where the 'year_founded' column is NaN or empty
print("\nNumber of rows where the 'year_founded' column is NaN or empty:")
print(len(nan_or_empty_rows))
# Out:
# Nombre de lignes dont la colonne 'year_founded' est NaN ou vide :
# 1080

# %% [markdown]
# #Hypothesis: Replace null values in "year_founded" with the year corresponding to the startups' batches

# %%
# Function to extract the year from the batch
def extract_year_from_batch(batch):
    if pd.notna(batch):
        if batch.startswith('W') or batch.startswith('S'):
            if len(batch) == 3 and batch[1:].isdigit():
                year_str = batch[1:]  # Remove the first character (W or S)
                return float(f"20{year_str}")
        elif batch.startswith('IK'):
            if len(batch) == 4 and batch[2:].isdigit():
                year_str = batch[2:]  # Remove the first two characters (IK)
                return float(f"20{year_str}")
    return None

# Apply the function to the 'year_founded' column to fill missing or null values
def update_year_founded(row):
    if pd.isna(row['year_founded']) or row['year_founded'] == '':
        year_founded = extract_year_from_batch(row['batch'])
        if year_founded is None:
            print(f"No valid batch found for {row['company_name']} with batch: {row['batch']}")
        return year_founded
    return row['year_founded']

df['year_founded'] = df.apply(update_year_founded, axis=1)
# Save the updated data
df.to_csv('/content/2024-05-11-yc-companies.csv', index=False)
df.head()
# Out:
#    company_id   company_name  \
# 0       29523   K-Scale Labs
# 1       29519  Forge Rewards
# 2       29517    RetailReady
# 3       29610     Hamming AI
# 4       29518        FanCave
#
#                                    short_description  \
# 0                        Open-source humanoid robots
# 1  All-in-one operations software to power restau...
# 2       An AI-powered supply chain compliance engine
# 3                                 Making AI reliable
# 4         Powering the free agency of college sports
#
#                                     long_description batch  status  \
# 0  We're building humanoid robots to do most of w...   W24  Active
# 1  Forge is the modern operations software for em...   W24  Active
# 2  Every time workers in a warehouse box an order...   W24  Active
# 3  If 2023 was the year of AI POCs, 2024 is the y...   S24  Active
# 4  FanCave powers the free agency of college spor...   W24  Active
#
#                                                 tags          location  \
# 0  ['artificial-intelligence', 'machine-learning'...          New York
# 1                     ['fintech', 'food-tech', 'ai']     San Francisco
# 2  ['b2b', 'compliance', 'logistics', 'supply-cha...               NaN
# 3  ['artificial-intelligence', 'developer-tools',...     San Francisco
# 4  ['marketplace', 'sports-tech', 'consumer', 'en...  Roeland Park, KS
#
#   country  year_founded  num_founders  \
# 0     USA        2024.0             3
# 1     USA        2023.0             2
# 2     NaN        2024.0             2
# 3     USA        2024.0             2
# 4     USA        2024.0             2
#
#                                       founders_names  team_size  \
# 0  ['Benjamin Bolte', 'Pawel Budzianowski', 'Matt...          3
# 1                       ['Ethan Chang', 'Isaac Kan']          2
# 2                      ['Elle Smyth', 'Sarah Hamer']          3
# 3             ['Marius Buleandra', 'Sumanyu Sharma']          2
# 4                      ['Luke Bogus', 'Nick Siscoe']          2
#
#                           website  \
# 0             https://kscale.dev/
# 1   https://www.forgerewards.com/
# 2  https://www.retailreadyai.com/
# 3             https://hamming.ai/
# 4          https://www.fancave.me
#
#                                               cb_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  https://www.crunchbase.com/organization/hammin...
# 4                                                NaN
#
#                                       linkedin_url
# 0         https://www.linkedin.com/company/kscale/
# 1        https://linkedin.com/company/forgerewards
# 2  https://www.linkedin.com/company/retailreadyai/
# 3     https://www.linkedin.com/company/hamming-ai/
# 4        https://www.linkedin.com/company/fancave/

# %%
# Check for missing or empty values in the 'year_founded' column
nan_or_empty_rows = df[df['year_founded'].isna() | (df['year_founded'].astype(str).str.strip() == '')]

# Display the number of rows where the 'year_founded' column is NaN or empty
print("\nNumber of rows where the 'year_founded' column is NaN or empty:")
print(len(nan_or_empty_rows))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5bda8cf452dd> in <cell line: 2>()
#       1 # Check for missing or empty values in the 'year_founded' column
# ----> 2 nan_or_empty_rows = df[df['year_founded'].isna() | (df['year_founded'].astype(str).str.strip() == '')]
#       3
#       4 # Display the number of rows where the 'year_founded' column is NaN or empty
#       5 print("\nNumber of rows where the 'year_founded' column is NaN or empty:")
#
# NameError: name 'df' is not defined

# %%
# Convert the values in the 'year_founded' column to integers
df['year_founded'] = df['year_founded'].astype(int)
df.head()
# Out:
#    company_id   company_name  \
# 0       29523   K-Scale Labs
# 1       29519  Forge Rewards
# 2       29517    RetailReady
# 3       29610     Hamming AI
# 4       29518        FanCave
#
#                                    short_description  \
# 0                        Open-source humanoid robots
# 1  All-in-one operations software to power restau...
# 2       An AI-powered supply chain compliance engine
# 3                                 Making AI reliable
# 4         Powering the free agency of college sports
#
#                                     long_description batch  status  \
# 0  We're building humanoid robots to do most of w...   W24  Active
# 1  Forge is the modern operations software for em...   W24  Active
# 2  Every time workers in a warehouse box an order...   W24  Active
# 3  If 2023 was the year of AI POCs, 2024 is the y...   S24  Active
# 4  FanCave powers the free agency of college spor...   W24  Active
#
#                                                 tags          location  \
# 0  ['artificial-intelligence', 'machine-learning'...          New York
# 1                     ['fintech', 'food-tech', 'ai']     San Francisco
# 2  ['b2b', 'compliance', 'logistics', 'supply-cha...               NaN
# 3  ['artificial-intelligence', 'developer-tools',...     San Francisco
# 4  ['marketplace', 'sports-tech', 'consumer', 'en...  Roeland Park, KS
#
#   country  year_founded  num_founders  \
# 0     USA          2024             3
# 1     USA          2023             2
# 2     NaN          2024             2
# 3     USA          2024             2
# 4     USA          2024             2
#
#                                       founders_names  team_size  \
# 0  ['Benjamin Bolte', 'Pawel Budzianowski', 'Matt...          3
# 1                       ['Ethan Chang', 'Isaac Kan']          2
# 2                      ['Elle Smyth', 'Sarah Hamer']          3
# 3             ['Marius Buleandra', 'Sumanyu Sharma']          2
# 4                      ['Luke Bogus', 'Nick Siscoe']          2
#
#                           website  \
# 0             https://kscale.dev/
# 1   https://www.forgerewards.com/
# 2  https://www.retailreadyai.com/
# 3             https://hamming.ai/
# 4          https://www.fancave.me
#
#                                               cb_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  https://www.crunchbase.com/organization/hammin...
# 4                                                NaN
#
#                                       linkedin_url
# 0         https://www.linkedin.com/company/kscale/
# 1        https://linkedin.com/company/forgerewards
# 2  https://www.linkedin.com/company/retailreadyai/
# 3     https://www.linkedin.com/company/hamming-ai/
# 4        https://www.linkedin.com/company/fancave/

# %%
# Check if columns exist before dropping them
columns_to_drop = ['cb_url', 'linkedin_url']
for column in columns_to_drop:
    if column in df.columns:
        df = df.drop(columns=[column])
df.head()
# Out:
#    company_id   company_name  \
# 0       29523   K-Scale Labs
# 1       29519  Forge Rewards
# 2       29517    RetailReady
# 3       29610     Hamming AI
# 4       29518        FanCave
#
#                                    short_description  \
# 0                        Open-source humanoid robots
# 1  All-in-one operations software to power restau...
# 2       An AI-powered supply chain compliance engine
# 3                                 Making AI reliable
# 4         Powering the free agency of college sports
#
#                                     long_description batch  status  \
# 0  We're building humanoid robots to do most of w...   W24  Active
# 1  Forge is the modern operations software for em...   W24  Active
# 2  Every time workers in a warehouse box an order...   W24  Active
# 3  If 2023 was the year of AI POCs, 2024 is the y...   S24  Active
# 4  FanCave powers the free agency of college spor...   W24  Active
#
#                                                 tags          location  \
# 0  ['artificial-intelligence', 'machine-learning'...          New York
# 1                     ['fintech', 'food-tech', 'ai']     San Francisco
# 2  ['b2b', 'compliance', 'logistics', 'supply-cha...               NaN
# 3  ['artificial-intelligence', 'developer-tools',...     San Francisco
# 4  ['marketplace', 'sports-tech', 'consumer', 'en...  Roeland Park, KS
#
#   country  year_founded  num_founders  \
# 0     USA          2024             3
# 1     USA          2023             2
# 2     NaN          2024             2
# 3     USA          2024             2
# 4     USA          2024             2
#
#                                       founders_names  team_size  \
# 0  ['Benjamin Bolte', 'Pawel Budzianowski', 'Matt...          3
# 1                       ['Ethan Chang', 'Isaac Kan']          2
# 2                      ['Elle Smyth', 'Sarah Hamer']          3
# 3             ['Marius Buleandra', 'Sumanyu Sharma']          2
# 4                      ['Luke Bogus', 'Nick Siscoe']          2
#
#                           website
# 0             https://kscale.dev/
# 1   https://www.forgerewards.com/
# 2  https://www.retailreadyai.com/
# 3             https://hamming.ai/
# 4          https://www.fancave.me

# %% [markdown]
# #Split the 'tags' column into multiple separate columns

# %%
# Check if the 'tags' column exists
if 'tags' in df.columns:
    # Remove brackets and transform the 'tags' column into a Python list
    df['tags'] = df['tags'].apply(lambda x: ast.literal_eval(x))

    # Create new columns tag_1, tag_2, etc., based on the content of 'tags'
    max_tags = df['tags'].apply(len).max()
    for i in range(1, max_tags + 1):
        df[f'tag_{i}'] = df['tags'].apply(lambda x: x[i-1] if i-1 < len(x) else None)

    # Remove the 'tags' column
    df = df.drop(columns=['tags'])

# Add the 'quantity' column with the value 1 in each cell
df['quantity'] = 1
# Save the updated data
df.to_csv('/content/2024-05-11-yc-companies_NEW.csv', index=False)
df.head()
# Out:
#    company_id   company_name  \
# 0       29523   K-Scale Labs
# 1       29519  Forge Rewards
# 2       29517    RetailReady
# 3       29610     Hamming AI
# 4       29518        FanCave
#
#                                    short_description  \
# 0                        Open-source humanoid robots
# 1  All-in-one operations software to power restau...
# 2       An AI-powered supply chain compliance engine
# 3                                 Making AI reliable
# 4         Powering the free agency of college sports
#
#                                     long_description batch  status  \
# 0  We're building humanoid robots to do most of w...   W24  Active
# 1  Forge is the modern operations software for em...   W24  Active
# 2  Every time workers in a warehouse box an order...   W24  Active
# 3  If 2023 was the year of AI POCs, 2024 is the y...   S24  Active
# 4  FanCave powers the free agency of college spor...   W24  Active
#
#            location country  year_founded  num_founders  \
# 0          New York     USA          2024             3
# 1     San Francisco     USA          2023             2
# 2               NaN     NaN          2024             2
# 3     San Francisco     USA          2024             2
# 4  Roeland Park, KS     USA          2024             2
#
#                                       founders_names  team_size  \
# 0  ['Benjamin Bolte', 'Pawel Budzianowski', 'Matt...          3
# 1                       ['Ethan Chang', 'Isaac Kan']          2
# 2                      ['Elle Smyth', 'Sarah Hamer']          3
# 3             ['Marius Buleandra', 'Sumanyu Sharma']          2
# 4                      ['Luke Bogus', 'Nick Siscoe']          2
#
#                           website                    tag_1             tag_2  \
# 0             https://kscale.dev/  artificial-intelligence  machine-learning
# 1   https://www.forgerewards.com/                  fintech         food-tech
# 2  https://www.retailreadyai.com/                      b2b        compliance
# 3             https://hamming.ai/  artificial-intelligence   developer-tools
# 4          https://www.fancave.me              marketplace       sports-tech
#
#        tag_3          tag_4 tag_5 tag_6  quantity
# 0   robotics       consumer  None  None         1
# 1         ai           None  None  None         1
# 2  logistics   supply-chain    ai  None         1
# 3        b2b      analytics  None  None         1
# 4   consumer  entertainment  None  None         1
